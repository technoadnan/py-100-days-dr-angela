# %%
import pandas as pd
reviews = pd.read_csv("resources/wines_review.csv").head(5)
# Out:
# C:\Users\adpd1\AppData\Local\Temp\ipykernel_11908\3960242302.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  score  price           province  \
# 0                        VulkÃ Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# 2                                 NaN     87   14.0             Oregon
# 3                Reserve Late Harvest     87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block     87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN     Kerin Oâ€™Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                   Nicosia 2013 VulkÃ Bianco (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwineÂ      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwineÂ  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              Unnamed: 0   country  \
# firstEntry            0     Italy
# secondEntry           1  Portugal
# 2                     2        US
# 3                     3        US
# 4                     4        US
#
#                                                    description  \
# firstEntry   Aromas include tropical fruit, broom, brimston...
# secondEntry  This is ripe and fruity, a wine that is smooth...
# 2            Tart and snappy, the flavors of lime flesh and...
# 3            Pineapple rind, lemon pith and orange blossom ...
# 4            Much like the regular bottling from 2012, this...
#
#                                     designation  points  price  \
# firstEntry                         VulkÃ Bianco      87    NaN
# secondEntry                            Avidagos      87   15.0
# 2                                           NaN      87   14.0
# 3                          Reserve Late Harvest      87   13.0
# 4            Vintner's Reserve Wild Child Block      87   65.0
#
#                       province             region_1           region_2  \
# firstEntry   Sicily & Sardinia                 Etna                NaN
# secondEntry              Douro                  NaN                NaN
# 2                       Oregon    Willamette Valley  Willamette Valley
# 3                     Michigan  Lake Michigan Shore                NaN
# 4                       Oregon    Willamette Valley  Willamette Valley
#
#                     taster_name taster_twitter_handle  \
# firstEntry      Kerin Oâ€™Keefe          @kerinokeefe
# secondEntry          Roger Voss            @vossroger
# 2                  Paul Gregutt           @paulgwineÂ
# 3            Alexander Peartree                   NaN
# 4                  Paul Gregutt           @paulgwineÂ
#
#                                                          title  \
# firstEntry                    Nicosia 2013 VulkÃ Bianco (Etna)
# secondEntry      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2                Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3            St. Julian 2013 Reserve Late Harvest Riesling ...
# 4            Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#                     variety               winery
# firstEntry      White Blend              Nicosia
# secondEntry  Portuguese Red  Quinta dos Avidagos
# 2                Pinot Gris            Rainstorm
# 3                  Riesling           St. Julian
# 4                Pinot Noir         Sweet Cheeks

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
#
# fields                         designation  points  price           province  \
# wines
# 0                             VulkÃ Bianco      87    NaN  Sicily & Sardinia
# 1                                 Avidagos      87   15.0              Douro
# 2                                      NaN      87   14.0             Oregon
# 3                     Reserve Late Harvest      87   13.0           Michigan
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
# fields             region_1           region_2         taster_name  \
# wines
# 0                      Etna                NaN     Kerin Oâ€™Keefe
# 1                       NaN                NaN          Roger Voss
# 2         Willamette Valley  Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore                NaN  Alexander Peartree
# 4         Willamette Valley  Willamette Valley        Paul Gregutt
#
# fields taster_twitter_handle  \
# wines
# 0               @kerinokeefe
# 1                 @vossroger
# 2                @paulgwineÂ
# 3                        NaN
# 4                @paulgwineÂ
#
# fields                                              title         variety  \
# wines
# 0                        Nicosia 2013 VulkÃ Bianco (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
# fields               winery
# wines
# 0                   Nicosia
# 1       Quinta dos Avidagos
# 2                 Rainstorm
# 3                St. Julian
# 4              Sweet Cheeks

# %% [markdown]
# ### Combining

# %%
water = pd.read_csv("resources/waterquality.csv").head(5)

# %%
pd.concat([reviews, water])
# Out:
#    Unnamed: 0   country                                        description  \
# 0         0.0     Italy  Aromas include tropical fruit, broom, brimston...
# 1         1.0  Portugal  This is ripe and fruity, a wine that is smooth...
# 2         2.0        US  Tart and snappy, the flavors of lime flesh and...
# 3         3.0        US  Pineapple rind, lemon pith and orange blossom ...
# 4         4.0        US  Much like the regular bottling from 2012, this...
# 0         NaN       NaN                                                NaN
# 1         NaN       NaN                                                NaN
# 2         NaN       NaN                                                NaN
# 3         NaN       NaN                                                NaN
# 4         NaN       NaN                                                NaN
#
#                           designation  points  price           province  \
# 0                        VulkÃ Bianco    87.0    NaN  Sicily & Sardinia
# 1                            Avidagos    87.0   15.0              Douro
# 2                                 NaN    87.0   14.0             Oregon
# 3                Reserve Late Harvest    87.0   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block    87.0   65.0             Oregon
# 0                                 NaN     NaN    NaN                NaN
# 1                                 NaN     NaN    NaN                NaN
# 2                                 NaN     NaN    NaN                NaN
# 3                                 NaN     NaN    NaN                NaN
# 4                                 NaN     NaN    NaN                NaN
#
#               region_1           region_2         taster_name  ...  \
# 0                 Etna                NaN     Kerin Oâ€™Keefe  ...
# 1                  NaN                NaN          Roger Voss  ...
# 2    Willamette Valley  Willamette Valley        Paul Gregutt  ...
# 3  Lake Michigan Shore                NaN  Alexander Peartree  ...
# 4    Willamette Valley  Willamette Valley        Paul Gregutt  ...
# 0                  NaN                NaN                 NaN  ...
# 1                  NaN                NaN                 NaN  ...
# 2                  NaN                NaN                 NaN  ...
# 3                  NaN                NaN                 NaN  ...
# 4                  NaN                NaN                 NaN  ...
#
#           variety               winery        Date Salinity (ppt)  \
# 0     White Blend              Nicosia         NaN            NaN
# 1  Portuguese Red  Quinta dos Avidagos         NaN            NaN
# 2      Pinot Gris            Rainstorm         NaN            NaN
# 3        Riesling           St. Julian         NaN            NaN
# 4      Pinot Noir         Sweet Cheeks         NaN            NaN
# 0             NaN                  NaN  1989-05-11            NaN
# 1             NaN                  NaN  1989-05-18            NaN
# 2             NaN                  NaN  1989-05-25            NaN
# 3             NaN                  NaN  1989-06-01            NaN
# 4             NaN                  NaN  1989-07-11            NaN
#
#   DissolvedOxygen (mg/L)   pH  SecchiDepth (m)  WaterDepth (m)  WaterTemp (C)  \
# 0                    NaN  NaN              NaN             NaN            NaN
# 1                    NaN  NaN              NaN             NaN            NaN
# 2                    NaN  NaN              NaN             NaN            NaN
# 3                    NaN  NaN              NaN             NaN            NaN
# 4                    NaN  NaN              NaN             NaN            NaN
# 0                    NaN  7.5              0.3             0.9           17.0
# 1                   12.0  7.5              0.2             0.6           17.5
# 2                    NaN  8.0              0.4             0.8           23.0
# 3                   12.0  8.0              0.4             0.9           25.5
# 4                    NaN  8.5              0.3             0.9           28.5
#
#    AirTemp (C)
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 0   -17.777778
# 1    20.500000
# 2    25.000000
# 3    29.000000
# 4    28.000000
#
# [10 rows x 22 columns]
