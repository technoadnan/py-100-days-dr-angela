# %%
import pandas as pd

# %%
file = pd.read_csv("resources/waterquality.csv")

# %%
file.set_index(range(len(file)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22836\2256301198.py in ?()
# ----> 1 file.set_index(range(len(file)))
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6102                     if not found:
#    6103                         missing.append(col)
#    6104
#    6105         if missing:
# -> 6106             raise KeyError(f"None of {missing} are in the columns")
#    6107
#    6108         if inplace:
#    6109             frame = self
#
# KeyError: 'None of [range(0, 198)] are in the columns'

# %%
file
# Out:
#            Date  Salinity (ppt)  DissolvedOxygen (mg/L)   pH  SecchiDepth (m)  \
# 0    1989-05-11             NaN                     NaN  7.5             0.30
# 1    1989-05-18             NaN                    12.0  7.5             0.20
# 2    1989-05-25             NaN                     NaN  8.0             0.40
# 3    1989-06-01             NaN                    12.0  8.0             0.40
# 4    1989-07-11             NaN                     NaN  8.5             0.30
# ..          ...             ...                     ...  ...              ...
# 193  1994-04-11             1.0                     8.6  7.3             0.20
# 194  1994-04-18             1.0                     8.8  7.6             0.20
# 195  1994-04-25             1.0                    10.0  7.9             0.20
# 196  1994-05-02             1.3                     9.8  7.5             0.20
# 197  1994-05-09             1.0                    10.1  7.9             0.25
#
# ...

# %%
file.groupby('AirTemp (C)')["AirTemp (C)"].max()
# Out:
# AirTemp (C)
# -17.777778   -17.777778
# -1.111111     -1.111111
#  0.000000      0.000000
#  0.500000      0.500000
#  1.000000      1.000000
#                 ...
#  30.000000    30.000000
#  30.500000    30.500000
#  31.000000    31.000000
#  31.500000    31.500000
#  32.500000    32.500000
# Name: AirTemp (C), Length: 72, dtype: float64
